# %% [markdown]
# <a href="https://colab.research.google.com/github/vitor172010/P.-A./blob/main/caixa%20eletronico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
saldo = 1000.00
opcao = 0

while opcao != 4:
    print("\n--- CAIXA ELETRÔNICO ---")
    print("1 - Ver saldo")
    print("2 - Depositar dinheiro")
    print("3 - Sacar dinheiro")
    print("4 - Sair")

    opcao = int(input("\nEscolha uma opção: "))

    if opcao == 1:
        print(f"Seu saldo atual é: R$ {saldo:.2f}")

    elif opcao == 2:
        valor_deposito = float(input("Digite o valor do depósito: R$ "))
        if valor_deposito > 0:
            saldo += valor_deposito
            print("Depósito realizado com sucesso!")
        else:
            print("Valor inválido para depósito.")

    elif opcao == 3:
        valor_saque = float(input("Digite o valor do saque: R$ "))
        if 0 < valor_saque <= saldo:
            saldo -= valor_saque
            print("Saque realizado com sucesso!")
        else:
            print("Saldo insuficiente ou valor inválido.")

    elif opcao == 4:
        print("Encerrando o sistema. Até logo!")

    else:
        print("Opção inválida. Tente novamente.")
# Out:
# --- CAIXA ELETRÔNICO ---
# 1 - Ver saldo
# 2 - Depositar dinheiro
# 3 - Sacar dinheiro
# 4 - Sair
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4630/2888021302.py in <cell line: 0>()
#       9     print("4 - Sair")
#      10
# ---> 11     opcao = int(input("\nEscolha uma opção: "))
#      12
#      13     if opcao == 1:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# Calculadora simples
opcao = 0
a = 0
b = 0

while opcao != 6:
    print("\nopção - 1 - Seja bem vindo")
    print("opção - 2 - Somar")
    print("opção - 3 - Subtrair")
    print("opção - 4 - Multiplicar")
    print("opção - 5 - Dividir")
    print("opção - 6 - Sair")

    opcao = int(input("digite a opção desejada: "))

    if opcao == 1:
        print("seja bem vindo")

    elif opcao == 2:
        a = int(input("digite o primeiro valor: "))
        b = int(input("digite o segundo valor: "))
        print(f"Total: {a + b}")

    elif opcao == 3:
        a = int(input("digite o primeiro valor: "))
        b = int(input("digite o segundo valor: "))
        print(f"Total: {a - b}")

    elif opcao == 4:
        a = int(input("digite o primeiro valor: "))
        b = int(input("digite o segundo valor: "))
        print(f"Total: {a * b}")

    elif opcao == 5:
        a = int(input("digite o primeiro valor: "))
        b = int(input("digite o segundo valor: "))
        if b != 0:
            print(f"Total: {a / b}")
        else:
            print("Não é possível dividir por zero!")

print("Programa encerrado.")
