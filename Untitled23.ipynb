# %% [markdown]
# <a href="https://colab.research.google.com/github/vitor172010/P.-A./blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input("Digite a idade da pessoa: "))

if idade >= 18:
    print("A pessoa pode tirar carteira de motorista.")
else:
    print("A pessoa NÃO pode tirar carteira de motorista.")
# Out:
# Digite a idade da pessoa: 43
# A pessoa pode tirar carteira de motorista.

# %% [markdown]
# ### Exercício 2 – Par ou Ímpar

# %%
numero = int(input("Digite um número inteiro: "))

if numero % 2 == 0:
    print(f"O número {numero} é PAR.")
else:
    print(f"O número {numero} é ÍMPAR.")
# Out:
# Digite um número inteiro: 50
# O número 50 é PAR.

# %% [markdown]
# ### Exercício 3 – Maior de dois números

# %%
numero1 = float(input("Digite o primeiro número: "))
numero2 = float(input("Digite o segundo número: "))

if numero1 > numero2:
    print(f"O primeiro número ({numero1}) é maior que o segundo número ({numero2}).")
elif numero2 > numero1:
    print(f"O segundo número ({numero2}) é maior que o primeiro número ({numero1}).")
else:
    print(f"Os dois números são iguais ({numero1}).")
# Out:
# Digite o primeiro número: 4
# Digite o segundo número: 6
# O segundo número (6.0) é maior que o primeiro número (4.0).

# %% [markdown]
# ### Exercício 4 – Situação do aluno

# %%
nota = float(input("Digite a nota do aluno: "))

if nota >= 7:
    print("Situação: Aprovado")
elif nota >= 5 and nota < 7:
    print("Situação: Recuperação")
else:
    print("Situação: Reprovado")
# Out:
# Digite a nota do aluno: 5
# Situação: Recuperação

# %% [markdown]
# ### Exercício 5 – Desconto na compra

# %%
valor_compra = float(input("Digite o valor da compra: "))

if valor_compra >= 100:
    valor_final = valor_compra * 0.90  # Aplica 10% de desconto (multiplica por 0.90)
    print(f"Valor da compra com desconto: R$ {valor_final:.2f}")
else:
    print(f"Valor da compra sem desconto: R$ {valor_compra:.2f}")
# Out:
# Digite o valor da compra: 5000
# Valor da compra com desconto: R$ 4500.00

# %% [markdown]
# ### Exercício 6 – Positivo, Negativo ou Zero

# %%
numero = float(input("Digite um número: "))

if numero > 0:
    print(f"O número {numero} é POSITIVO.")
elif numero < 0:
    print(f"O número {numero} é NEGATIVO.")
else:
    print(f"O número é ZERO.")

# %% [markdown]
# ### Exercício 7 – Classificação de idade

# %%
idade = int(input("Digite a idade da pessoa: "))

if idade < 12:
    print("Classificação: Criança")
elif idade >= 12 and idade <= 17:
    print("Classificação: Adolescente")
elif idade >= 18 and idade <= 59:
    print("Classificação: Adulto")
else:
    print("Classificação: Idoso")

# %% [markdown]
# ### Exercício 8 – Média de duas notas

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))

media = (nota1 + nota2) / 2

print(f"A média do aluno é: {media:.2f}")

if media >= 7:
    print("Situação: Aprovado")
else:
    print("Situação: Reprovado")

# %% [markdown]
# ### Exercício 9 – Login simples

# %%
usuario = input("Digite o nome de usuário: ")
senha = input("Digite a senha: ")

if usuario == "admin" and senha == "1234":
    print("Login realizado com sucesso!")
else:
    print("Usuário ou senha incorretos.")

# %% [markdown]
# ### Exercício 10 – Calculadora de IMC

# %%
peso = float(input("Digite o seu peso (em kg): "))
altura = float(input("Digite a sua altura (em metros): "))

imc = peso / (altura * altura)

print(f"Seu IMC é: {imc:.2f}")

if imc < 18.5:
    print("Classificação: Abaixo do peso")
elif imc >= 18.5 and imc <= 24.9:
    print("Classificação: Peso normal")
elif imc >= 25 and imc <= 29.9:
    print("Classificação: Sobrepeso")
else:
    print("Classificação: Obesidade")
